# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork865-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>
#
# <h1 align=center><font size = 5>Assignment: SQL Notebook for Peer Assignment</font></h1>
#
# Estimated time needed: **60** minutes.
#
# ## Introduction
# Using this Python notebook you will:
#
# 1.  Understand the Spacex DataSet
# 2.  Load the dataset  into the corresponding table in a Db2 database
# 3.  Execute SQL queries to answer assignment questions

# %% [markdown]
# ## Overview of the DataSet
#
# SpaceX has gained worldwide attention for a series of historic milestones.
#
# It is the only private company ever to return a spacecraft from low-earth orbit, which it first accomplished in December 2010.
# SpaceX advertises Falcon 9 rocket launches on its website with a cost of 62 million dollars wheras other providers cost upward of 165 million dollars each, much of the savings is because Space X can reuse the first stage.
#
#
# Therefore if we can determine if the first stage will land, we can determine the cost of a launch.
#
# This information can be used if an alternate company wants to bid against SpaceX for a rocket launch.
#
# This dataset includes a record for each payload carried during a SpaceX mission into outer space.

# %% [markdown]
# ### Download the datasets
#
# This assignment requires you to load the spacex dataset.
#
# In many cases the dataset to be analyzed is available as a .CSV (comma separated values) file, perhaps on the internet. Click on the link below to download and save the dataset (.CSV file):
#
#  <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/data/Spacex.csv" target="_blank">Spacex DataSet</a>

# %%
# !pip install sqlalchemy==1.3.9
# Out:
# Collecting sqlalchemy==1.3.9
#   Downloading SQLAlchemy-1.3.9.tar.gz (6.0 MB)
#      ---------------------------------------- 6.0/6.0 MB 325.2 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: sqlalchemy
#   Building wheel for sqlalchemy (setup.py): started
#   Building wheel for sqlalchemy (setup.py): finished with status 'done'
#   Created wheel for sqlalchemy: filename=SQLAlchemy-1.3.9-cp37-cp37m-win_amd64.whl size=1163297 sha256=55fcc2b9af8a429b5361f7e202243083db443c71b36b32453a844b749f329afe
#   Stored in directory: c:\users\abodr\appdata\local\pip\cache\wheels\ef\95\ac\c232f83b415900c26553c64266e1a2b2863bc63e7a5d606c7e
# Successfully built sqlalchemy
# Installing collected packages: sqlalchemy
# Successfully installed sqlalchemy-1.3.9

# %% [markdown]
# ### Connect to the database
#
# Let us first load the SQL extension and establish a connection with the database

# %%
# !pip install ipython-sql
# %load_ext sql
# Out:
# Collecting ipython-sqlThe sql module is not an IPython extension.
#
#   Downloading ipython_sql-0.5.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: ipython-genutils in c:\users\abodr\miniconda3\envs\tf_2.6\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: ipython in c:\users\abodr\miniconda3\envs\tf_2.6\lib\site-packages (from ipython-sql) (7.31.1)
# Requirement already satisfied: six in c:\users\abodr\miniconda3\envs\tf_2.6\lib\site-packages (from ipython-sql) (1.16.0)
# Collecting prettytable
#   Downloading prettytable-3.6.0-py3-none-any.whl (27 kB)
# Collecting sqlalchemy>=2.0
#   Downloading SQLAlchemy-2.0.7-cp37-cp37m-win_amd64.whl (2.0 MB)
#      ---------------------------------------- 2.0/2.0 MB 307.9 kB/s eta 0:00:00
# Collecting sqlparse
#   Downloading sqlparse-0.4.3-py3-none-any.whl (42 kB)
#      -------------------------------------- 42.8/42.8 kB 692.1 kB/s eta 0:00:00
# Collecting greenlet!=0.4.17
#   Downloading greenlet-2.0.2-cp37-cp37m-win_amd64.whl (192 kB)
#      ------------------------------------ 192.4/192.4 kB 342.4 kB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata in c:\users\abodr\miniconda3\envs\tf_2.6\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.11.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\abodr\miniconda3\envs\tf_2.6\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.4.0)
# Requirement already satisfied: matplotlib-inline in c:\users\abodr\miniconda3\envs\tf_2.6\lib\site-packages (from ipython->ipython-sql) (0.1.6)
# Requirement already satisfied: backcall in c:\users\abodr\miniconda3\envs\tf_2.6\lib\site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: colorama in c:\users\abodr\miniconda3\envs\tf_2.6\lib\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: jedi>=0.16 in c:\users\abodr\miniconda3\envs\tf_2.6\lib\site-packages (from ipython->ipython-sql) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\abodr\miniconda3\envs\tf_2.6\lib\site-packages (from ipython->ipython-sql) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in c:\users\abodr\miniconda3\envs\tf_2.6\lib\site-packages (from ipython->ipython-sql) (65.6.3)
# Requirement already satisfied: traitlets>=4.2 in c:\users\abodr\miniconda3\envs\tf_2.6\lib\site-packages (from ipython->ipython-sql) (5.7.1)
# Requirement already satisfied: pygments in c:\users\abodr\miniconda3\envs\tf_2.6\lib\site-packages (from ipython->ipython-sql) (2.11.2)
# Requirement already satisfied: decorator in c:\users\abodr\miniconda3\envs\tf_2.6\lib\site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\abodr\miniconda3\envs\tf_2.6\lib\site-packages (from ipython->ipython-sql) (3.0.36)
# Requirement already satisfied: wcwidth in c:\users\abodr\miniconda3\envs\tf_2.6\lib\site-packages (from prettytable->ipython-sql) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\abodr\miniconda3\envs\tf_2.6\lib\site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: zipp>=0.5 in c:\users\abodr\miniconda3\envs\tf_2.6\lib\site-packages (from importlib-metadata->sqlalchemy>=2.0->ipython-sql) (3.11.0)
# Installing collected packages: sqlparse, greenlet, sqlalchemy, prettytable, ipython-sql
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.3.9
#     Uninstalling SQLAlchemy-1.3.9:
#       Successfully uninstalled SQLAlchemy-1.3.9
# Successfully installed greenlet-2.0.2 ipython-sql-0.5.0 prettytable-3.6.0 sqlalchemy-2.0.7 sqlparse-0.4.3

# %%
import csv, sqlite3

con = sqlite3.connect("my_data1.db")
cur = con.cursor()

# %%
# !pip install -q pandas==1.1.5

# %%
# %load_ext sql

# %%
# %sql sqlite:///my_data1.db
# Out:
# 'Connected: @my_data1.db'

# %%
import pandas as pd
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/data/Spacex.csv")
df.to_sql("SPACEXTBL", con, if_exists='replace', index=False,method="multi")
df.head(20)
# Out:
# c:\Users\abodr\miniconda3\envs\tf_2.6\lib\site-packages\pandas\core\generic.py:2882: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,
#           Date Time (UTC) Booster_Version  Launch_Site  \
# 0   04-06-2010   18:45:00  F9 v1.0  B0003  CCAFS LC-40
# 1   08-12-2010   15:43:00  F9 v1.0  B0004  CCAFS LC-40
# 2   22-05-2012   07:44:00  F9 v1.0  B0005  CCAFS LC-40
# 3   08-10-2012   00:35:00  F9 v1.0  B0006  CCAFS LC-40
# 4   01-03-2013   15:10:00  F9 v1.0  B0007  CCAFS LC-40
# 5   29-09-2013   16:00:00  F9 v1.1  B1003  VAFB SLC-4E
# 6   03-12-2013   22:41:00         F9 v1.1  CCAFS LC-40
# 7   06-01-2014   22:06:00         F9 v1.1  CCAFS LC-40
# 8   18-04-2014   19:25:00         F9 v1.1  CCAFS LC-40
# 9   14-07-2014   15:15:00         F9 v1.1  CCAFS LC-40
# 10  05-08-2014   08:00:00         F9 v1.1  CCAFS LC-40
# 11  07-09-2014   05:00:00   F9 v1.1 B1011  CCAFS LC-40
# 12  21-09-2014   05:52:00   F9 v1.1 B1010  CCAFS LC-40
# 13  10-01-2015   09:47:00   F9 v1.1 B1012  CCAFS LC-40
# 14  11-02-2015   23:03:00   F9 v1.1 B1013  CCAFS LC-40
# 15  02-03-2015   03:50:00   F9 v1.1 B1014  CCAFS LC-40
# 16  14-04-2015   20:10:00   F9 v1.1 B1015  CCAFS LC-40
# 17  27-04-2015   23:03:00   F9 v1.1 B1016  CCAFS LC-40
# 18  28-06-2015   14:21:00   F9 v1.1 B1018  CCAFS LC-40
# 19  22-12-2015   01:29:00     F9 FT B1019  CCAFS LC-40
#
#                                               Payload  PAYLOAD_MASS__KG_  \
# 0                Dragon Spacecraft Qualification Unit                  0
# 1   Dragon demo flight C1, two CubeSats, barrel of...                  0
# 2                               Dragon demo flight C2                525
# 3                                        SpaceX CRS-1                500
# 4                                        SpaceX CRS-2                677
# 5                                            CASSIOPE                500
# 6                                               SES-8               3170
# 7                                           Thaicom 6               3325
# 8                                        SpaceX CRS-3               2296
# 9             OG2 Mission 1  6 Orbcomm-OG2 satellites               1316
# 10                                          AsiaSat 8               4535
# 11                                          AsiaSat 6               4428
# 12                                       SpaceX CRS-4               2216
# 13                                       SpaceX CRS-5               2395
# 14                                             DSCOVR                570
# 15                         ABS-3A Eutelsat 115 West B               4159
# 16                                       SpaceX CRS-6               1898
# 17                             Turkmen 52 / MonacoSAT               4707
# 18                                       SpaceX CRS-7               1952
# 19           OG2 Mission 2  11 Orbcomm-OG2 satellites               2034
#
#         Orbit                            Customer      Mission_Outcome  \
# 0         LEO                              SpaceX              Success
# 1   LEO (ISS)                     NASA (COTS) NRO              Success
# 2   LEO (ISS)                         NASA (COTS)              Success
# 3   LEO (ISS)                          NASA (CRS)              Success
# 4   LEO (ISS)                          NASA (CRS)              Success
# 5   Polar LEO                                 MDA              Success
# 6         GTO                                 SES              Success
# 7         GTO                             Thaicom              Success
# 8   LEO (ISS)                          NASA (CRS)              Success
# 9         LEO                             Orbcomm              Success
# 10        GTO                             AsiaSat              Success
# 11        GTO                             AsiaSat              Success
# 12  LEO (ISS)                          NASA (CRS)              Success
# 13  LEO (ISS)                          NASA (CRS)              Success
# 14        HEO            U.S. Air Force NASA NOAA              Success
# 15        GTO                        ABS Eutelsat              Success
# 16  LEO (ISS)                          NASA (CRS)              Success
# 17        GTO  Turkmenistan National Space Agency              Success
# 18  LEO (ISS)                          NASA (CRS)  Failure (in flight)
# 19        LEO                             Orbcomm              Success
#
#           Landing _Outcome
# 0      Failure (parachute)
# 1      Failure (parachute)
# 2               No attempt
# 3               No attempt
# 4               No attempt
# 5     Uncontrolled (ocean)
# 6               No attempt
# 7               No attempt
# 8       Controlled (ocean)
# 9       Controlled (ocean)
# 10              No attempt
# 11              No attempt
# 12    Uncontrolled (ocean)
# 13    Failure (drone ship)
# 14      Controlled (ocean)
# 15              No attempt
# 16    Failure (drone ship)
# 17              No attempt
# 18  Precluded (drone ship)
# 19    Success (ground pad)

# %% [markdown]
# ## Tasks
#
# Now write and execute SQL queries to solve the assignment tasks.
#
# **Note: If the column names are in mixed case enclose it in double quotes
#    For Example "Landing_Outcome"**
#
# ### Task 1
#
#
#
#
# ##### Display the names of the unique launch sites  in the space mission

# %%
# %sql select distinct "Launch_site" from SPACEXTBL
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('CCAFS LC-40',), ('VAFB SLC-4E',), ('KSC LC-39A',), ('CCAFS SLC-40',)]

# %% [markdown]
# ### Task 2
#
#
# #####  Display 5 records where launch sites begin with the string 'CCA'

# %%
# %sql select Launch_Site from SPACEXTBL where Launch_Site like '%CCA%' limit 5
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('CCAFS LC-40',),
#  ('CCAFS LC-40',),
#  ('CCAFS LC-40',),
#  ('CCAFS LC-40',),
#  ('CCAFS LC-40',)]

# %% [markdown]
# ### Task 3
#
#
#
#
# ##### Display the total payload mass carried by boosters launched by NASA (CRS)

# %%
# %sql select sum(PAYLOAD_MASS__KG_) from SPACEXTBL group by Booster_Version
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(2647,),
#  (5384,),
#  (9600,),
#  (6460,),
#  (3310,),
#  (4990,),
#  (9600,),
#  (3500,),
#  (5000,),
#  (6092,),
#  (362,),
#  (2697,),
#  (3600,),
#  (5800,),
#  (4000,),
#  (12050,),
#  (5300,),
#  (6500,),
#  (3000,),
#  (4850,),
#  (15600,),
#  (15600,),
#  (9600,),
#  (13620,),
#  (15600,),
#  (15600,),
#  (15440,),
#  (15600,),
#  (4200,),
#  (15600,),
#  (15600,),
#  (14932,),
#  (15600,),
#  (2268,),
#  (6956,),
#  (15600,),
#  (5500,),
#  (15600,),
#  (2972,),
#  (1977,),
#  (15410,),
#  (3130,),
#  (15600,),
#  (15600,),
#  (7075,),
#  (9600,),
#  (7060,),
#  (2500,),
#  (12055,),
#  (4400,),
#  (2495,),
#  (12530,),
#  (2617,),
#  (4311,),
#  (12500,),
#  (4311,),
#  (1192,),
#  (5300,),
#  (3669,),
#  (5200,),
#  (4230,),
#  (2205,),
#  (9600,),
#  (2150,),
#  (2034,),
#  (5271,),
#  (3136,),
#  (4696,),
#  (3100,),
#  (3600,),
#  (2257,),
#  (4600,),
#  (9600,),
#  (5600,),
#  (2490,),
#  (5300,),
#  (6070,),
#  (2708,),
#  (9600,),
#  (6761,),
#  (475,),
#  (0,),
#  (0,),
#  (525,),
#  (500,),
#  (677,),
#  (14642,),
#  (500,),
#  (2216,),
#  (4428,),
#  (2395,),
#  (570,),
#  (4159,),
#  (1898,),
#  (4707,),
#  (553,),
#  (1952,)]

# %% [markdown]
# ### Task 4
#
#
#
#
# ##### Display average payload mass carried by booster version F9 v1.1

# %%
# %sql select avg(PAYLOAD_MASS__KG_) from SPACEXTBL where Booster_Version like "F9 v1.1%"
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(2534.6666666666665,)]

# %% [markdown]
# ### Task 5
#
# ##### List the date when the first succesful landing outcome in ground pad was acheived.
#
#
# _Hint:Use min function_

# %%
# %sql select min(date) from SPACEXTBL where Mission_Outcome == "Success"
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('01-03-2013',)]

# %% [markdown]
# ### Task 6
#
# ##### List the names of the boosters which have success in drone ship and have payload mass greater than 4000 but less than 6000

# %%
# %sql select distinct Booster_Version from SPACEXTBL where (PAYLOAD_MASS__KG_ between 4000 and 6000) and ("Landing_Outcome" like 'Success (drone ship)')
# Out:
#  * sqlite:///my_data1.db
# Done.
# []

# %% [markdown]
# ### Task 7
#
#
#
#
# ##### List the total number of successful and failure mission outcomes

# %%
# %sql select  Mission_Outcome,count(*) from SPACEXTBL group by Mission_Outcome
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('Failure (in flight)', 1),
#  ('Success', 98),
#  ('Success ', 1),
#  ('Success (payload status unclear)', 1)]

# %% [markdown]
# ### Task 8
#
#
#
# ##### List the   names of the booster_versions which have carried the maximum payload mass. Use a subquery

# %%
# %sql select Booster_Version,max(PAYLOAD_MASS__KG_) from SPACEXTBL group by Booster_Version
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('F9 B4  B1039.2', 2647),
#  ('F9 B4  B1040.2', 5384),
#  ('F9 B4  B1041.2', 9600),
#  ('F9 B4  B1043.2', 6460),
#  ('F9 B4 B1039.1', 3310),
#  ('F9 B4 B1040.1', 4990),
#  ('F9 B4 B1041.1', 9600),
#  ('F9 B4 B1042.1', 3500),
#  ('F9 B4 B1043.1', 5000),
#  ('F9 B4 B1044', 6092),
#  ('F9 B4 B1045.1', 362),
#  ('F9 B4 B1045.2', 2697),
#  ('F9 B5  B1046.1', 3600),
#  ('F9 B5 B1046.2', 5800),
#  ('F9 B5 B1046.3', 4000),
#  ('F9 B5 B1046.4', 12050),
#  ('F9 B5 B1047.2', 5300),
#  ('F9 B5 B1047.3 ', 6500),
#  ('F9 B5 B1048.2', 3000),
#  ('F9 B5 B1048.3', 4850),
#  ('F9 B5 B1048.4', 15600),
#  ('F9 B5 B1048.5', 15600),
#  ('F9 B5 B1049.2', 9600),
#  ('F9 B5 B1049.3', 13620),
#  ('F9 B5 B1049.4', 15600),
#  ('F9 B5 B1049.5', 15600),
#  ('F9 B5 B1049.6', 15440),
#  ('F9 B5 B1049.7 ', 15600),
#  ('F9 B5 B1051.2 ', 4200),
#  ('F9 B5 B1051.3', 15600),
#  ('F9 B5 B1051.4', 15600),
#  ('F9 B5 B1051.5', 14932),
#  ('F9 B5 B1051.6', 15600),
#  ('F9 B5 B1056.2 ', 2268),
#  ('F9 B5 B1056.3 ', 6956),
#  ('F9 B5 B1056.4', 15600),
#  ('F9 B5 B1058.2 ', 5500),
#  ('F9 B5 B1058.3 ', 15600),
#  ('F9 B5 B1058.4 ', 2972),
#  ('F9 B5 B1059.2', 1977),
#  ('F9 B5 B1059.3', 15410),
#  ('F9 B5 B1059.4', 3130),
#  ('F9 B5 B1060.2 ', 15600),
#  ('F9 B5 B1060.3', 15600),
#  ('F9 B5B1047.1', 7075),
#  ('F9 B5B1048.1', 9600),
#  ('F9 B5B1049.1', 7060),
#  ('F9 B5B1050', 2500),
#  ('F9 B5B1051.1', 12055),
#  ('F9 B5B1054', 4400),
#  ('F9 B5B1056.1 ', 2495),
#  ('F9 B5B1058.1 ', 12530),
#  ('F9 B5B1059.1', 2617),
#  ('F9 B5B1060.1', 4311),
#  ('F9 B5B1061.1 ', 12500),
#  ('F9 B5B1062.1', 4311),
#  ('F9 B5B1063.1', 1192),
#  ('F9 FT  B1021.2', 5300),
#  ('F9 FT  B1029.2', 3669),
#  ('F9 FT  B1031.2', 5200),
#  ('F9 FT  B1032.2', 4230),
#  ('F9 FT  B1035.2', 2205),
#  ('F9 FT  B1036.2', 9600),
#  ('F9 FT  B1038.2', 2150),
#  ('F9 FT B1019', 2034),
#  ('F9 FT B1020', 5271),
#  ('F9 FT B1021.1', 3136),
#  ('F9 FT B1022', 4696),
#  ('F9 FT B1023.1', 3100),
#  ('F9 FT B1024', 3600),
#  ('F9 FT B1025.1', 2257),
#  ('F9 FT B1026', 4600),
#  ('F9 FT B1029.1', 9600),
#  ('F9 FT B1030', 5600),
#  ('F9 FT B1031.1', 2490),
#  ('F9 FT B1032.1', 5300),
#  ('F9 FT B1034', 6070),
#  ('F9 FT B1035.1', 2708),
#  ('F9 FT B1036.1', 9600),
#  ('F9 FT B1037', 6761),
#  ('F9 FT B1038.1', 475),
#  ('F9 v1.0  B0003', 0),
#  ('F9 v1.0  B0004', 0),
#  ('F9 v1.0  B0005', 525),
#  ('F9 v1.0  B0006', 500),
#  ('F9 v1.0  B0007', 677),
#  ('F9 v1.1', 4535),
#  ('F9 v1.1  B1003', 500),
#  ('F9 v1.1 B1010', 2216),
#  ('F9 v1.1 B1011', 4428),
#  ('F9 v1.1 B1012', 2395),
#  ('F9 v1.1 B1013', 570),
#  ('F9 v1.1 B1014', 4159),
#  ('F9 v1.1 B1015', 1898),
#  ('F9 v1.1 B1016', 4707),
#  ('F9 v1.1 B1017', 553),
#  ('F9 v1.1 B1018', 1952)]

# %% [markdown]
# ### Task 9
#
#
# ##### List the records which will display the month names, failure landing_outcomes in drone ship ,booster versions, launch_site for the months in year 2015.
#
# **Note: SQLLite does not support monthnames. So you need to use  substr(Date, 4, 2) as month to get the months and substr(Date,7,4)='2015' for year.**

# %% [markdown]
# ### Task 10
#
#
#
#
# ##### Rank the  count of  successful landing_outcomes between the date 04-06-2010 and 20-03-2017 in descending order.

# %%
# %sql select "Landing _Outcome",count(*) from SPACEXTBL where "Date" between "04-06-2010" and "20-03-2017"  group by (select distinct "Landing _Outcome" from SPACEXTBL where "Landing _Outcome" like "Success%") order by count("Landing _Outcome") desc
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('Failure (parachute)', 57)]

# %%
# %sql select "Landing _Outcome" from SPACEXTBL group by (select"Landing _Outcome" from SPACEXTBL where "Landing _Outcome" like "Success%")
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('Failure (parachute)',)]

# %% [markdown]
# ### Reference Links
#
# * <a href ="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20String%20Patterns%20-%20Sorting%20-%20Grouping/instructional-labs.md.html?origin=www.coursera.org">Hands-on Lab : String Patterns, Sorting and Grouping</a>
#
# *  <a  href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20Built-in%20functions%20/Hands-on_Lab__Built-in_Functions.md.html?origin=www.coursera.org">Hands-on Lab: Built-in functions</a>
#
# *  <a  href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20Sub-queries%20and%20Nested%20SELECTs%20/instructional-labs.md.html?origin=www.coursera.org">Hands-on Lab : Sub-queries and Nested SELECT Statements</a>
#
# *   <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Module%205/DB0201EN-Week3-1-3-SQLmagic.ipynb">Hands-on Tutorial: Accessing Databases with SQL magic</a>
#
# *  <a href= "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Module%205/DB0201EN-Week3-1-4-Analyzing.ipynb">Hands-on Lab: Analyzing a real World Data Set</a>

# %% [markdown]
# ## Author(s)
#
# <h4> Lakshmi Holla </h4>

# %% [markdown]
# ## Other Contributors
#
# <h4> Rav Ahuja </h4>

# %% [markdown]
# ## Change log
# | Date | Version | Changed by | Change Description |
# |------|--------|--------|---------|
# | 2021-07-09 | 0.2 |Lakshmi Holla | Changes made in magic sql|
# | 2021-05-20 | 0.1 |Lakshmi Holla | Created Initial Version |

# %% [markdown]
# ## <h3 align="center"> © IBM Corporation 2021. All rights reserved. <h3/>
